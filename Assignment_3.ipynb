# %% [markdown]
# <a href="https://colab.research.google.com/github/deepali25-05/DS_Rcodes/blob/main/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from scipy import stats
from scipy.stats import norm

cutlets= pd.read_csv("/content/Cutlets.csv")

# %%
cutlets
# Out:
#     Unit A  Unit B
# 0   6.8090  6.7703
# 1   6.4376  7.5093
# 2   6.9157  6.7300
# 3   7.3012  6.7878
# 4   7.4488  7.1522
# 5   7.3871  6.8110
# 6   6.8755  7.2212
# 7   7.0621  6.6606
# 8   6.6840  7.2402
# 9   6.8236  7.0503
# 10  7.3930  6.8810
# 11  7.5169  7.4059
# 12  6.9246  6.7652
# 13  6.9256  6.0380
# 14  6.5797  7.1581
# 15  6.8394  7.0240
# 16  6.5970  6.6672
# 17  7.2705  7.4314
# 18  7.2828  7.3070
# 19  7.3495  6.7478
# 20  6.9438  6.8889
# 21  7.1560  7.4220
# 22  6.5341  6.5217
# 23  7.2854  7.1688
# 24  6.9952  6.7594
# 25  6.8568  6.9399
# 26  7.2163  7.0133
# 27  6.6801  6.9182
# 28  6.9431  6.3346
# 29  7.0852  7.5459
# 30  6.7794  7.0992
# 31  7.2783  7.1180
# 32  7.1561  6.6965
# 33  7.3943  6.5780
# 34  6.9405  7.3875

# %%
cutlets.head()
# Out:
#    Unit A  Unit B
# 0  6.8090  6.7703
# 1  6.4376  7.5093
# 2  6.9157  6.7300
# 3  7.3012  6.7878
# 4  7.4488  7.1522

# %%
unitA=pd.Series(cutlets.iloc[:,0])
unitA
# Out:
# 0     6.8090
# 1     6.4376
# 2     6.9157
# 3     7.3012
# 4     7.4488
# 5     7.3871
# 6     6.8755
# 7     7.0621
# 8     6.6840
# 9     6.8236
# 10    7.3930
# 11    7.5169
# 12    6.9246
# 13    6.9256
# 14    6.5797
# 15    6.8394
# 16    6.5970
# 17    7.2705
# 18    7.2828
# 19    7.3495
# 20    6.9438
# 21    7.1560
# 22    6.5341
# 23    7.2854
# 24    6.9952
# 25    6.8568
# 26    7.2163
# 27    6.6801
# 28    6.9431
# 29    7.0852
# 30    6.7794
# 31    7.2783
# 32    7.1561
# 33    7.3943
# 34    6.9405
# Name: Unit A, dtype: float64

# %%
unitB=pd.Series(cutlets.iloc[:,1])
unitB
# Out:
# 0     6.7703
# 1     7.5093
# 2     6.7300
# 3     6.7878
# 4     7.1522
# 5     6.8110
# 6     7.2212
# 7     6.6606
# 8     7.2402
# 9     7.0503
# 10    6.8810
# 11    7.4059
# 12    6.7652
# 13    6.0380
# 14    7.1581
# 15    7.0240
# 16    6.6672
# 17    7.4314
# 18    7.3070
# 19    6.7478
# 20    6.8889
# 21    7.4220
# 22    6.5217
# 23    7.1688
# 24    6.7594
# 25    6.9399
# 26    7.0133
# 27    6.9182
# 28    6.3346
# 29    7.5459
# 30    7.0992
# 31    7.1180
# 32    6.6965
# 33    6.5780
# 34    7.3875
# Name: Unit B, dtype: float64

# %%
p_value=stats.ttest_ind(unitA,unitB)

# %%
p_value
# Out:
# Ttest_indResult(statistic=0.7228688704678061, pvalue=0.4722394724599501)

# %%
# HO is accepted. Thats is both Y1 and Y2 are normal

import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import norm

# %%
data=pd.read_csv("/content/LabTAT.csv")

# %%
data
# Out:
#      Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0          185.35        165.53        176.70        166.13
# 1          170.49        185.91        198.45        160.79
# 2          192.77        194.92        201.23        185.18
# 3          177.33        183.00        199.61        176.42
# 4          193.41        169.57        204.63        152.60
# ..            ...           ...           ...           ...
# 115        178.49        170.66        193.80        172.68
# 116        176.08        183.98        215.25        177.64
# 117        202.48        174.54        203.99        170.27
# 118        182.40        197.18        194.52        150.87
# 119        182.09        215.17        221.49        162.21
#
# [120 rows x 4 columns]

# %%
data.head()
# Out:
#    Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0        185.35        165.53        176.70        166.13
# 1        170.49        185.91        198.45        160.79
# 2        192.77        194.92        201.23        185.18
# 3        177.33        183.00        199.61        176.42
# 4        193.41        169.57        204.63        152.60

# %%
# Anova ftest statistics: stats.f_oneway(column-1,column-2,column-3,column-4)
p_value=stats.f_oneway(data.iloc[:,0],data.iloc[:,1],data.iloc[:,2],data.iloc[:,3])
p_value
# Out:
# F_onewayResult(statistic=118.70421654401437, pvalue=2.1156708949992414e-57)

# %%
p_value[1]
# Out:
# 2.1156708949992414e-57

# %%
# P value of the One way Anova test is == 2e-16 < α
#Thus H1 is accepted.
#Mean TAT for 4 laboratories not equal

import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import norm

df=pd.read_csv("/content/BuyerRatio.csv")

# %%
df.head()
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
stats.chi2_contingency([df['East'],df['West'],df['North'],df['South']])
# Out:
# (1.5959455386610577,
#  0.6603094907091882,
#  3,
#  array([[  42.76531299,  442.23468701],
#         [ 146.81287862, 1518.18712138],
#         [ 131.11756787, 1355.88243213],
#         [  72.30424052,  747.69575948]]))

# %%
#p value of chi square test is o.66 >a
#Thus H0 is accepted.
#The male-female buyer rations are similar across regions

import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import norm

# %%
df=pd.read_csv("/content/Costomer+OrderForm.csv")

# %%
df.head()
# Out:
#   Phillippines   Indonesia       Malta       India
# 0   Error Free  Error Free   Defective  Error Free
# 1   Error Free  Error Free  Error Free   Defective
# 2   Error Free   Defective   Defective  Error Free
# 3   Error Free  Error Free  Error Free  Error Free
# 4   Error Free  Error Free   Defective  Error Free

# %%
stats.chi2_contingency([df['India'].value_counts(),df['Indonesia'].value_counts(),df['Malta'].value_counts(),df['Phillippines'].value_counts()])
# Out:
# (3.8589606858203545, 0.2771020991233144, 3, array([[271.75,  28.25],
#         [271.75,  28.25],
#         [271.75,  28.25],
#         [271.75,  28.25]]))

# %%
#P value of Chi-Square test == 0.277 > α

#Thus HO is accepted.
#The defective % does not varies significantly by centres
